# %% [markdown]
# use [pydantic-ai](https://ai.pydantic.dev/) to develop a simple agent.

# %%
# setup config

import os

base_url = os.getenv("BASE_URL", "DEFAULT")
api_key = os.getenv("API_KEY", "DEFAULT")
model = os.getenv("MODEL", "DEFAULT")

# %%
# setup llm

from pydantic_ai.providers.openai import OpenAIProvider

llm = OpenAIProvider(base_url=base_url, api_key=api_key)
